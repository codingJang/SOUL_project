# %%
# %pip install torch
# %pip install cmake
# %pip install swig
# %pip install gym
# %pip install 'pettingzoo[all]'
# %pip install matplotlib
# Out:
# Requirement already satisfied: torch in /opt/homebrew/lib/python3.11/site-packages (2.1.0)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from torch) (3.12.4)
# Requirement already satisfied: typing-extensions in /opt/homebrew/lib/python3.11/site-packages (from torch) (4.8.0)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/homebrew/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/homebrew/lib/python3.11/site-packages (from torch) (2023.9.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: cmake in /opt/homebrew/lib/python3.11/site-packages (3.27.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: swig in /opt/homebrew/lib/python3.11/site-packages (4.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gym in /opt/homebrew/lib/python3.11/site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in /opt/homebrew/lib/python3.11/site-packages (from gym) (1.26.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/homebrew/lib/python3.11/site-packages (from gym) (0.0.8)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pettingzoo[all] in /opt/homebrew/lib/python3.11/site-packages (1.24.1)
# Requirement already satisfied: numpy>=1.21.0 in /opt/homebrew/lib/python3.11/site-packages (from pettingzoo[all]) (1.26.0)
# Requirement already satisfied: gymnasium>=0.28.0 in /opt/homebrew/lib/python3.11/site-packages (from pettingzoo[all]) (0.29.1)
# Requirement already satisfied: multi-agent-ale-py==0.1.11 in /opt/homebrew/lib/python3.11/site-packages (from pettingzoo[all]) (0.1.11)
# Requirement already satisfied: pygame==2.3.0 in /opt/homebrew/lib/python3.11/site-packages (from pettingzoo[all]) (2.3.0)
# Requirement already satisfied: chess==1.9.4 in /opt/homebrew/lib/python3.11/site-packages (from pettingzoo[all]) (1.9.4)
# Requirement already satisfied: rlcard==1.0.5 in /opt/homebrew/lib/python3.11/site-packages (from pettingzoo[all]) (1.0.5)
# Requirement already satisfied: shimmy>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from shimmy[openspiel]>=1.2.0; extra == "all"->pettingzoo[all]) (1.2.1)
# Requirement already satisfied: pymunk==6.2.0 in /opt/homebrew/lib/python3.11/site-packages (from pettingzoo[all]) (6.2.0)
# Requirement already satisfied: box2d-py==2.3.5 in /opt/homebrew/lib/python3.11/site-packages (from pettingzoo[all]) (2.3.5)
# Requirement already satisfied: scipy>=1.4.1 in /opt/homebrew/lib/python3.11/site-packages (from pettingzoo[all]) (1.11.3)
# Requirement already satisfied: pillow>=8.0.1 in /opt/homebrew/lib/python3.11/site-packages (from pettingzoo[all]) (10.0.1)
# Requirement already satisfied: cffi>1.14.0 in /opt/homebrew/lib/python3.11/site-packages (from pymunk==6.2.0->pettingzoo[all]) (1.16.0)
# Requirement already satisfied: termcolor in /opt/homebrew/lib/python3.11/site-packages (from rlcard==1.0.5->pettingzoo[all]) (2.3.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from gymnasium>=0.28.0->pettingzoo[all]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/homebrew/lib/python3.11/site-packages (from gymnasium>=0.28.0->pettingzoo[all]) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/homebrew/lib/python3.11/site-packages (from gymnasium>=0.28.0->pettingzoo[all]) (0.0.4)
# Requirement already satisfied: open-spiel>=1.2 in /opt/homebrew/lib/python3.11/site-packages (from shimmy[openspiel]>=1.2.0; extra == "all"->pettingzoo[all]) (1.3)
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.11/site-packages (from cffi>1.14.0->pymunk==6.2.0->pettingzoo[all]) (2.21)
# Requirement already satisfied: pip>=20.0.2 in /opt/homebrew/lib/python3.11/site-packages (from open-spiel>=1.2->shimmy[openspiel]>=1.2.0; extra == "all"->pettingzoo[all]) (23.3)
# Requirement already satisfied: attrs>=19.3.0 in /opt/homebrew/lib/python3.11/site-packages (from open-spiel>=1.2->shimmy[openspiel]>=1.2.0; extra == "all"->pettingzoo[all]) (23.1.0)
# Requirement already satisfied: absl-py>=0.10.0 in /opt/homebrew/lib/python3.11/site-packages (from open-spiel>=1.2->shimmy[openspiel]>=1.2.0; extra == "all"->pettingzoo[all]) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.11/site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /Users/jang-yejun/Library/Python/3.11/lib/python/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jang-yejun/Library/Python/3.11/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/jang-yejun/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from pettingzoo.mpe import simple_v3, simple_spread_v3
import gym

class DeepQNetwork(nn.Module):
    # 멤버 객체 설정 및 저장
    def __init__(self, state_dims, c_h_sizes, v_h_sizes, a_h_sizes, n_actions, lr=0.003):
        super(DeepQNetwork, self).__init__()
        self.state_dims = state_dims
        self.c_h_sizes = c_h_sizes
        self.v_h_sizes = v_h_sizes
        self.a_h_sizes = a_h_sizes
        self.n_actions = n_actions
        self.c_layers = nn.ModuleList()
        self.v_layers = nn.ModuleList()
        self.a_layers = nn.ModuleList()

        self.c_layers.append(nn.Linear(*state_dims, c_h_sizes[0]))
        self.c_layers.append(nn.ReLU())
        for i in range(len(c_h_sizes)-1):
            self.c_layers.append(nn.Linear(c_h_sizes[i], c_h_sizes[i+1]))
            self.c_layers.append(nn.ReLU())
        
        self.v_layers.append(nn.Linear(c_h_sizes[-1], v_h_sizes[0]))
        self.v_layers.append(nn.ReLU())
        for i in range(len(v_h_sizes)-1):
            self.v_layers.append(nn.Linear(v_h_sizes[i], v_h_sizes[i+1]))
            self.v_layers.append(nn.ReLU())
        self.v_layers.append(nn.Linear(v_h_sizes[-1], 1))

        self.a_layers.append(nn.Linear(c_h_sizes[-1], a_h_sizes[0]))
        self.a_layers.append(nn.ReLU())
        for i in range(len(a_h_sizes)-1):
            self.a_layers.append(nn.Linear(a_h_sizes[i], a_h_sizes[i+1]))
            self.a_layers.append(nn.ReLU())
        self.a_layers.append(nn.Linear(a_h_sizes[-1], n_actions))

        self.optimizer = optim.Adam(self.parameters(), lr=lr)
        self.loss = nn.MSELoss()
        self.device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
        self.to(self.device)
    # state를 받아서 각 action에 대한 예상 Q-value를 벡터로 반환 : Q(s)[a]
    def forward(self, x):
        for layer in self.c_layers:
            x = layer(x)
        y = x.clone()
        for layer in self.v_layers:
            x = layer(x)
        for layer in self.a_layers:
            y = layer(y)
        mean_y = torch.mean(y, dim=-1, keepdim=True)
        # print(f"x.size={x.size()}")
        # print(f"y.size={y.size()}")
        # print(f"mean_y.size={mean_y.size()}")
        out = x + (y - mean_y)
        # print(f"out.size()={out.size()}")
        # print(out)
        return out


class DuelingDeepQLearningAgent:
    def __init__(self, state_dims, n_actions, gamma=0.99, eps=1.0, 
                 a=None, lr=0.003, c_h_sizes=[64], v_h_sizes=[32, 32], a_h_sizes=[32, 32], 
                 batch_size=64, mem_size=50000):
        self.state_dims = state_dims
        self.n_actions = n_actions
        self.gamma = gamma
        self.eps = eps
        self.a = a
        self.lr = lr
        self.v_h_sizes = v_h_sizes
        self.a_h_sizes = a_h_sizes
        self.c_h_sizes = c_h_sizes
        self.batch_size = batch_size
        self.mem_size = mem_size

        self.Q_eval = DeepQNetwork(state_dims, c_h_sizes, v_h_sizes, a_h_sizes, n_actions, lr=lr)

        self.action_space = gym.spaces.Discrete(n_actions)
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *state_dims), dtype=np.float32)
        self.action_memory = -1 * np.ones(self.mem_size, dtype=np.int32)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.next_state_memory = np.zeros((self.mem_size, *state_dims), dtype=np.float32)
        self.termination_memory = np.zeros(self.mem_size, dtype=np.bool_)
        self.truncation_memory = np.zeros(self.mem_size, dtype=np.bool_)

    def store_transition(self, state, action, reward, next_state, terminated, truncated):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.next_state_memory[index] = next_state
        self.termination_memory[index] = terminated
        self.truncation_memory[index] = truncated
        self.mem_cntr += 1
    
    def choose_action(self, state):
        if np.random.random() < self.eps:
            # action = np.random.choice(self.action_space).item()
            action = self.action_space.sample()
        else:
            with torch.no_grad():
                state = torch.Tensor(state, device=self.Q_eval.device)
                Q_vals = self.Q_eval.forward(state)
                action = torch.argmax(Q_vals).item()
        return action
    
    def learn(self):
        if self.mem_cntr < self.batch_size:
            return
        self.Q_eval.optimizer.zero_grad()
        max_mem = min(self.mem_cntr, self.mem_size)
        if self.a is not None:
            self.eps = self.a / (self.a + self.mem_cntr)
        batch = np.random.choice(max_mem, size=self.batch_size, replace=False)
        batch_index = torch.arange(self.batch_size, dtype=torch.int32)
        
        state_batch = torch.Tensor(self.state_memory[batch], device=self.Q_eval.device).float()
        action_batch = torch.Tensor(self.action_memory[batch], device=self.Q_eval.device).int()
        reward_batch = torch.Tensor(self.reward_memory[batch], device=self.Q_eval.device).float()
        next_state_batch = torch.Tensor(self.next_state_memory[batch], device=self.Q_eval.device).float()
        termination_batch = torch.Tensor(self.termination_memory[batch], device=self.Q_eval.device).bool()
        truncation_batch = torch.Tensor(self.truncation_memory[batch], device=self.Q_eval.device).bool()

        q = self.Q_eval.forward(state_batch)[batch_index, action_batch]
        q_next = self.Q_eval.forward(next_state_batch)
        q_next[termination_batch] = 0.0
        q_next[truncation_batch] = 0.0
        q_target = reward_batch + self.gamma * torch.max(q_next, dim=-1)[0]
        loss = self.Q_eval.loss(q_target.detach(), q).to(self.Q_eval.device)
        loss.backward()
        self.Q_eval.optimizer.step()
    

if __name__ == '__main__':
    # PettingZoo 환경 생성
    env = simple_spread_v3.parallel_env(render_mode="human")
    env.reset()
    n_agents = env.num_agents
    state_dims = env.observation_space(env.possible_agents[0]).shape
    n_actions = env.action_space(env.possible_agents[0]).n

    # 변수 선언
    agent_instances = {agent:DuelingDeepQLearningAgent(state_dims=state_dims, n_actions=n_actions, gamma=0.9, 
                                                a=60000, lr=0.0003, c_h_sizes=[64], v_h_sizes=[32, 32], a_h_sizes=[32, 32], mem_size=50000) for agent in env.agents}
    score_history, eps_history = [], []
    n_episodes = 20000
    stop_learning = 19000

    # 게임을 여러 차례 돌린다
    for episode in range(n_episodes):
        # 변수 선언
        obs, infos = env.reset()
        scores = {agent:0 for agent in env.agents}
        dones = {agent:False for agent in env.agents}
        epsilons = {agent:agent_instances[agent].eps for agent in env.agents}
        # 게임 종료 전까지 s, a, r, s' 및 종료 정보 생성, 학습 및 기록
        while env.agents:  # 모든 에이전트가 종료되기 전까지
            actions = {agent:agent_instances[agent].choose_action(obs[agent]) for agent in env.agents}
            next_obs, rewards, terminations, truncations, _ = env.step(actions)
            for agent in env.agents:
                agent_instances[agent].store_transition(obs[agent], actions[agent], rewards[agent], next_obs[agent], 
                                                        terminations[agent], truncations[agent])
                if episode < stop_learning:
                    agent_instances[agent].learn()
                else:
                    agent_instances[agent].eps = 0.0
                scores[agent] += rewards[agent]
            obs = next_obs
        # 최종 점수 및 epsilon 기록
        score_history.append(scores)
        eps_history.append(epsilons)
        print('episode:', episode, 'scores:', scores, 'epsilons:', epsilons)
    env.close()
# Out:
# episode: 0 scores: {'agent_0': -24.613423648256152, 'agent_1': -24.613423648256152, 'agent_2': -24.613423648256152} epsilons: {'agent_0': 1.0, 'agent_1': 1.0, 'agent_2': 1.0}
# episode: 1 scores: {'agent_0': -24.06309353484135, 'agent_1': -24.06309353484135, 'agent_2': -24.06309353484135} epsilons: {'agent_0': 1.0, 'agent_1': 1.0, 'agent_2': 1.0}
# episode: 2 scores: {'agent_0': -28.566345256190964, 'agent_1': -28.566345256190964, 'agent_2': -27.066345256190964} epsilons: {'agent_0': 1.0, 'agent_1': 1.0, 'agent_2': 1.0}
# episode: 29 scores: {'agent_0': -32.07064142695479, 'agent_1': -31.570641426954797, 'agent_2': -32.07064142695479} epsilons: {'agent_0': 0.9885330170027679, 'agent_1': 0.9885330170027679, 'agent_2': 0.9885330170027679}
# episode: 30 scores: {'agent_0': -33.572515166132014, 'agent_1': -33.572515166132014, 'agent_2': -33.572515166132014} epsilons: {'agent_0': 0.9881422924901185, 'agent_1': 0.9881422924901185, 'agent_2': 0.9881422924901185}
# episode: 31 scores: {'agent_0': -28.58338788825943, 'agent_1': -30.08338788825943, 'agent_2': -30.08338788825943} epsilons: {'agent_0': 0.9877518767285658, 'agent_1': 0.9877518767285658, 'agent_2': 0.9877518767285658}
# episode: 32 scores: {'agent_0': -30.619552811518332, 'agent_1': -29.619552811518332, 'agent_2': -30.619552811518332} epsilons: {'agent_0': 0.9873617693522907, 'agent_1': 0.9873617693522907, 'agent_2': 0.9873617693522907}
# episode: 33 scores: {'agent_0': -15.65012098408987, 'agent_1': -15.65012098408987, 'agent_2': -15.65012098408987} epsilons: {'agent_0': 0.9869719699960521, 'agent_1': 0.9869719699960521, 'agent_2': 0.9869719699960521}
# episode: 34 scores: {'agent_0': -14.515932352910326, 'agent_1': -14.515932352910326, 'agent_2': -14.515932352910326} epsilons: {'agent_0': 0.9865824782951855, 'agent_1': 0.9865824782951855, 'agent_2': 0.9865824782951855}
# episode: 35 scores: {'agent_0': -30.32788501375752, 'agent_1': -31.82788501375752, 'agent_2': -31.82788501375752} epsilons: {'agent_0': 0.9861932938856016, 'agent_1': 0.9861932938856016, 'agent_2': 0.9861932938856016}
# episode: 36 scores: {'agent_0': -20.915012466627694, 'agent_1': -20.915012466627694, 'agent_2': -20.915012466627694} epsilons: {'agent_0': 0.9858044164037855, 'agent_1': 0.9858044164037855, 'agent_2': 0.9858044164037855}
# episode: 37 scores: {'agent_0': -23.323823559422863, 'agent_1': -23.323823559422863, 'agent_2': -23.323823559422863} epsilons: {'agent_0': 0.9854158454867954, 'agent_1': 0.9854158454867954, 'agent_2': 0.9854158454867954}
# episode: 38 scores: {'agent_0': -22.2907401288259, 'agent_1': -22.2907401288259, 'agent_2': -22.2907401288259} epsilons: {'agent_0': 0.9850275807722616, 'agent_1': 0.9850275807722616, 'agent_2': 0.9850275807722616}
# episode: 39 scores: {'agent_0': -21.97880353535517, 'agent_1': -21.97880353535517, 'agent_2': -21.97880353535517} epsilons: {'agent_0': 0.9846396218983852, 'agent_1': 0.9846396218983852, 'agent_2': 0.9846396218983852}
# episode: 40 scores: {'agent_0': -13.523122458310336, 'agent_1': -13.523122458310336, 'agent_2': -13.523122458310336} epsilons: {'agent_0': 0.984251968503937, 'agent_1': 0.984251968503937, 'agent_2': 0.984251968503937}
# episode: 41 scores: {'agent_0': -31.053230004704908, 'agent_1': -32.05323000470491, 'agent_2': -32.05323000470491} epsilons: {'agent_0': 0.9838646202282566, 'agent_1': 0.9838646202282566, 'agent_2': 0.9838646202282566}
# episode: 82 scores: {'agent_0': -35.81343422608889, 'agent_1': -35.81343422608889, 'agent_2': -35.81343422608889} epsilons: {'agent_0': 0.9682416731216111, 'agent_1': 0.9682416731216111, 'agent_2': 0.9682416731216111}
# episode: 83 scores: {'agent_0': -29.50388721232714, 'agent_1': -30.00388721232714, 'agent_2': -30.00388721232714} epsilons: {'agent_0': 0.9678668215253581, 'agent_1': 0.9678668215253581, 'agent_2': 0.9678668215253581}
# episode: 84 scores: {'agent_0': -35.48865392441357, 'agent_1': -35.48865392441357, 'agent_2': -35.48865392441357} epsilons: {'agent_0': 0.9674922600619195, 'agent_1': 0.9674922600619195, 'agent_2': 0.9674922600619195}
# episode: 85 scores: {'agent_0': -21.65416550003431, 'agent_1': -21.65416550003431, 'agent_2': -21.65416550003431} epsilons: {'agent_0': 0.9671179883945842, 'agent_1': 0.9671179883945842, 'agent_2': 0.9671179883945842}
# episode: 86 scores: {'agent_0': -25.982977786132317, 'agent_1': -25.982977786132317, 'agent_2': -22.482977786132317} epsilons: {'agent_0': 0.9667440061871616, 'agent_1': 0.9667440061871616, 'agent_2': 0.9667440061871616}
# episode: 87 scores: {'agent_0': -22.719781091079874, 'agent_1': -22.719781091079874, 'agent_2': -22.719781091079874} epsilons: {'agent_0': 0.9663703131039815, 'agent_1': 0.9663703131039815, 'agent_2': 0.9663703131039815}
# episode: 88 scores: {'agent_0': -24.537659356670343, 'agent_1': -24.537659356670343, 'agent_2': -24.537659356670343} epsilons: {'agent_0': 0.9659969088098919, 'agent_1': 0.9659969088098919, 'agent_2': 0.9659969088098919}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/jang-yejun/Projects/VSCodeProjects/SOUL_project/Source/MultiAgentDuelingDeepQLearning/MultiAgentDuelingDeepQLearning.ipynb Cell 2 line 1
#     <a href='vscode-notebook-cell:/Users/jang-yejun/Projects/VSCodeProjects/SOUL_project/Source/MultiAgentDuelingDeepQLearning/MultiAgentDuelingDeepQLearning.ipynb#W1sZmlsZQ%3D%3D?line=162'>163</a> while env.agents:  # 모든 에이전트가 종료되기 전까지
#     <a href='vscode-notebook-cell:/Users/jang-yejun/Projects/VSCodeProjects/SOUL_project/Source/MultiAgentDuelingDeepQLearning/MultiAgentDuelingDeepQLearning.ipynb#W1sZmlsZQ%3D%3D?line=163'>164</a>     actions = {agent:agent_instances[agent].choose_action(obs[agent]) for agent in env.agents}
# --> <a href='vscode-notebook-cell:/Users/jang-yejun/Projects/VSCodeProjects/SOUL_project/Source/MultiAgentDuelingDeepQLearning/MultiAgentDuelingDeepQLearning.ipynb#W1sZmlsZQ%3D%3D?line=164'>165</a>     next_obs, rewards, terminations, truncations, _ = env.step(actions)
#     <a href='vscode-notebook-cell:/Users/jang-yejun/Projects/VSCodeProjects/SOUL_project/Source/MultiAgentDuelingDeepQLearning/MultiAgentDuelingDeepQLearning.ipynb#W1sZmlsZQ%3D%3D?line=165'>166</a>     for agent in env.agents:
#     <a href='vscode-notebook-cell:/Users/jang-yejun/Projects/VSCodeProjects/SOUL_project/Source/MultiAgentDuelingDeepQLearning/MultiAgentDuelingDeepQLearning.ipynb#W1sZmlsZQ%3D%3D?line=166'>167</a>         agent_instances[agent].store_transition(obs[agent], actions[agent], rewards[agent], next_obs[agent],
#     <a href='vscode-notebook-cell:/Users/jang-yejun/Projects/VSCodeProjects/SOUL_project/Source/MultiAgentDuelingDeepQLearning/MultiAgentDuelingDeepQLearning.ipynb#W1sZmlsZQ%3D%3D?line=167'>168</a>                                                 terminations[agent], truncations[agent])
#
# File /opt/homebrew/lib/python3.11/site-packages/pettingzoo/utils/conversions.py:207, in aec_to_parallel_wrapper.step(self, actions)
#     203         raise AssertionError(
#     204             f"expected agent {agent} got agent {self.aec_env.agent_selection}, Parallel environment wrapper expects agents to step in a cycle."
#     205         )
#     206 obs, rew, termination, truncation, info = self.aec_env.last()
# --> 207 self.aec_env.step(actions[agent])
#     208 for agent in self.aec_env.agents:
#     209     rewards[agent] += self.aec_env.rewards[agent]
#
# File /opt/homebrew/lib/python3.11/site-packages/pettingzoo/utils/wrappers/order_enforcing.py:91, in OrderEnforcingWrapper.step(self, action)
#      89 else:
#      90     self._has_updated = True
# ---> 91     super().step(action)
#
# File /opt/homebrew/lib/python3.11/site-packages/pettingzoo/utils/wrappers/base.py:116, in BaseWrapper.step(self, action)
#     115 def step(self, action: ActionType) -> None:
# --> 116     self.env.step(action)
#     118     self.agent_selection = self.env.agent_selection
#     119     self.rewards = self.env.rewards
#
# File /opt/homebrew/lib/python3.11/site-packages/pettingzoo/utils/wrappers/assert_out_of_bounds.py:26, in AssertOutOfBoundsWrapper.step(self, action)
#      16 def step(self, action: ActionType) -> None:
#      17     assert (
#      18         action is None
#      19         and (
#    (...)
#      24         action
#      25     ), "action is not in action space"
# ---> 26     super().step(action)
#
# File /opt/homebrew/lib/python3.11/site-packages/pettingzoo/utils/wrappers/base.py:116, in BaseWrapper.step(self, action)
#     115 def step(self, action: ActionType) -> None:
# --> 116     self.env.step(action)
#     118     self.agent_selection = self.env.agent_selection
#     119     self.rewards = self.env.rewards
#
# File /opt/homebrew/lib/python3.11/site-packages/pettingzoo/mpe/_mpe_utils/simple_env.py:263, in SimpleEnv.step(self, action)
#     260 self._accumulate_rewards()
#     262 if self.render_mode == "human":
# --> 263     self.render()
#
# File /opt/homebrew/lib/python3.11/site-packages/pettingzoo/mpe/_mpe_utils/simple_env.py:279, in SimpleEnv.render(self)
#     275     return
#     277 self.enable_render(self.render_mode)
# --> 279 self.draw()
#     280 if self.render_mode == "rgb_array":
#     281     observation = np.array(pygame.surfarray.pixels3d(self.screen))
#
# File /opt/homebrew/lib/python3.11/site-packages/pettingzoo/mpe/_mpe_utils/simple_env.py:293, in SimpleEnv.draw(self)
#     291 # update bounds to center around agent
#     292 all_poses = [entity.state.p_pos for entity in self.world.entities]
# --> 293 cam_range = np.max(np.abs(np.array(all_poses)))
#     295 # update geometry and text positions
#     296 text_line = 0
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# Learning curve 그리기
def plot_learning_curve(score_history, eps_history, filename, lines=None):
    fig=plt.figure()
    ax1=fig.add_subplot(111, label="1")
    ax2=fig.add_subplot(111, label="2", frame_on=False)

    x = [i+1 for i in range(len(score_history))]
    y1 = [score_history[i]['agent_0'] for i in range(len(score_history))]
    y2 = [np.nan] * 50 + [np.mean(y1[i-50:i+50]) for i in range(50, len(eps_history)-50)] + [np.nan] * 50
    y3 = [eps_history[i]['agent_0'] for i in range(len(eps_history))]

    ax1.plot(x, y1, color="pink")
    ax1.plot(x, y2, color="red")
    ax2.plot(x, y3, color="blue")
    
    ax1.set_xlabel("# episodes", color="black")
    ax1.set_ylabel("Epsilons / scores", color="black")
    ax1.tick_params(axis='x', colors="black")
    ax1.tick_params(axis='y', colors="black")

    plt.savefig(filename)

# %%
a = agent_instances['agent_0']
filename = f"MADDQL_{env}_gamma={a.gamma:.3f}_" + (f"a={a.a}" if a.a is not None else f"eps={a.eps}") \
    + f"_lr={a.lr:.5f}_vhs={a.v_h_sizes}_ahs={a.a_h_sizes}_bs={a.batch_size}_ms={a.mem_size}_n_episodes={n_episodes}.png"
print(filename)
plot_learning_curve(score_history, eps_history, filename)
# Out:
# MADDQL_simple_spread_v3_gamma=0.900_a=60000_lr=0.00030_vhs=[32, 32]_ahs=[32, 32]_bs=64_ms=50000_n_episodes=20000.png
